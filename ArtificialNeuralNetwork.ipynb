# %% [markdown]
# # REDES NEURAIS ARTIFICIAIS
#
# [Aula 3 de Deep Learning](http://bit.ly/dn-unb03) da Engenharia de Software da UnB

# %% [markdown]
# # Parte 1 - Pré-processamento dos Dados

# %% [markdown]
# ### Importar as libs

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ### Importar o dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
#dataset = pd.read_csv('https://raw.githubusercontent.com/deeplearningunb/building-ann/master/Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values
print("X >>\n",X)
print("y >>\n",y)
# Out:
# X >>
#  [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]
# y >>
#  [1 0 1 ... 1 1 0]

# %% [markdown]
# ### Transformando os dados categóricos

# %%
# Label Encoding the "Gender" column
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])
print(X)
# One Hot Encoding the "Geography" column
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# # Dividindo o dataset em conjunto de treinamento e conjunto de teste

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
np.shape(X_train)
# Out:
# (8000, 12)

# %% [markdown]
# ---
# # Parte 2 -Vamos construir uma ANN!

# %% [markdown]
# ### Initializing the ANN

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=5, activation='selu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=4, activation='selu'))

# %% [markdown]
# ### Adding the output layer

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the ANN on the Training set

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 1ms/step - loss: 0.8402 - accuracy: 0.5561
# Epoch 2/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4828 - accuracy: 0.7956
# Epoch 3/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4549 - accuracy: 0.8015
# Epoch 4/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.8053
# Epoch 5/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8188
# Epoch 6/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.8245
# Epoch 7/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4099 - accuracy: 0.8257
# Epoch 8/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.8211
# Epoch 9/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8341
# Epoch 10/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8345
# Epoch 11/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3907 - accuracy: 0.8379
# Epoch 12/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3802 - accuracy: 0.8457
# Epoch 13/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3842 - accuracy: 0.8405
# Epoch 14/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3782 - accuracy: 0.8409
# Epoch 15/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3578 - accuracy: 0.8473
# Epoch 16/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8569
# Epoch 17/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3364 - accuracy: 0.8627
# Epoch 18/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8591
# Epoch 19/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3575 - accuracy: 0.8516
# Epoch 20/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3394 - accuracy: 0.8624
# Epoch 21/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3431 - accuracy: 0.8590
# Epoch 22/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3324 - accuracy: 0.8605
# Epoch 23/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3451 - accuracy: 0.8562
# Epoch 24/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3448 - accuracy: 0.8582
# Epoch 25/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8631
# Epoch 26/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3322 - accuracy: 0.8670
# Epoch 27/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3353 - accuracy: 0.8596
# Epoch 28/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.8585
# Epoch 29/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8665
# Epoch 30/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3385 - accuracy: 0.8606
# Epoch 31/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3472 - accuracy: 0.8603
# Epoch 32/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8622
# Epoch 33/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3344 - accuracy: 0.8647
# Epoch 34/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3377 - accuracy: 0.8614
# Epoch 35/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3356 - accuracy: 0.8601
# Epoch 36/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3515 - accuracy: 0.8577
# Epoch 37/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8610
# Epoch 38/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3127 - accuracy: 0.8742
# Epoch 39/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3245 - accuracy: 0.8695
# Epoch 40/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8645
# Epoch 41/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8597
# Epoch 42/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3320 - accuracy: 0.8634
# Epoch 43/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3401 - accuracy: 0.8570
# Epoch 44/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3283 - accuracy: 0.8656
# Epoch 45/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.8668
# Epoch 46/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8637
# Epoch 47/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3238 - accuracy: 0.8714
# Epoch 48/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3324 - accuracy: 0.8611
# Epoch 49/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8627
# Epoch 50/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3350 - accuracy: 0.8643
# Epoch 51/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8622
# Epoch 52/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3256 - accuracy: 0.8676
# Epoch 53/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3386 - accuracy: 0.8601
# Epoch 54/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8648
# Epoch 55/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3266 - accuracy: 0.8638
# Epoch 56/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3361 - accuracy: 0.8584
# Epoch 57/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3283 - accuracy: 0.8662
# Epoch 58/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3412 - accuracy: 0.8570
# Epoch 59/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3283 - accuracy: 0.8653
# Epoch 60/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3285 - accuracy: 0.8670
# Epoch 61/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3393 - accuracy: 0.8609
# Epoch 62/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3372 - accuracy: 0.8612
# Epoch 63/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8670
# Epoch 64/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3395 - accuracy: 0.8656
# Epoch 65/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3375 - accuracy: 0.8617
# Epoch 66/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3279 - accuracy: 0.8654
# Epoch 67/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3395 - accuracy: 0.8626
# Epoch 68/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8625
# Epoch 69/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3402 - accuracy: 0.8614
# Epoch 70/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3268 - accuracy: 0.8642
# Epoch 71/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3245 - accuracy: 0.8692
# Epoch 72/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3350 - accuracy: 0.8607
# Epoch 73/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3286 - accuracy: 0.8651
# Epoch 74/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3324 - accuracy: 0.8651
# Epoch 75/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3249 - accuracy: 0.8677
# Epoch 76/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8681
# Epoch 77/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3227 - accuracy: 0.8731
# Epoch 78/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3387 - accuracy: 0.8624
# Epoch 79/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.8648
# Epoch 80/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3339 - accuracy: 0.8580
# Epoch 81/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3232 - accuracy: 0.8699
# Epoch 82/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3248 - accuracy: 0.8658
# Epoch 83/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3380 - accuracy: 0.8603
# Epoch 84/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8666
# Epoch 85/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3231 - accuracy: 0.8704
# Epoch 86/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3437 - accuracy: 0.8574
# Epoch 87/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3225 - accuracy: 0.8700
# Epoch 88/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.8606
# Epoch 89/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3257 - accuracy: 0.8673
# Epoch 90/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3262 - accuracy: 0.8717
# Epoch 91/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3455 - accuracy: 0.8595
# Epoch 92/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3349 - accuracy: 0.8628
# Epoch 93/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8635
# Epoch 94/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8708
# Epoch 95/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3197 - accuracy: 0.8698
# Epoch 96/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3286 - accuracy: 0.8659
# Epoch 97/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3233 - accuracy: 0.8687
# Epoch 98/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3305 - accuracy: 0.8661
# Epoch 99/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3220 - accuracy: 0.8682
# Epoch 100/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3273 - accuracy: 0.8619

# %% [markdown]
# # Parte 3 - Fazendo predições e avaliando o modelo
#
# ## Prevendo os resultados com o conjunto de testes

# %%
y_pred = ann.predict(X_test)
y_pred
# Out:
# array([[0.22732735],
#        [0.25405574],
#        [0.12145758],
#        ...,
#        [0.16383654],
#        [0.11904526],
#        [0.21542141]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %% [markdown]
# # Criando uma Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1520   75]
#  [ 197  208]]

# %% [markdown]
# # FIM

# %% [markdown]
# > Professor Diego Dorgam
# > [@diegodorgam](https://twitter.com/diegodorgam)
